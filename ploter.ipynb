# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
g_los = np.load('identity_losses.npy')
plt.plot(g_los)
plt.title('Identity Loss')
plt.show()

# %%
g_los = np.load('g_losses.npy')
plt.plot(g_los)
plt.title('G Loss')
plt.show()

# %%
c_los = np.load('cycle_losses.npy')
plt.plot(c_los)
plt.title('Cycle Loss')
plt.show()

# %%
d_los = np.load('d_losses.npy')
plt.plot(d_los)
plt.title('D Loss')
plt.show()

# %%
gan_los = np.load('gan_losses.npy')
plt.plot(gan_los)
plt.title('GAN Loss')
plt.show()
